# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = "C:\\Users\\Republic Of Gamers\\OneDrive\\Documents\\GitHub\\TSDN-BoyWithLuv\\Source\\Data\\patient_cost_and_stay_data.csv"
df = pd.read_csv(path)
df
# Out:
#         Unnamed: 0  patient_id  gender  age          insurance_type  \
# 0                0           1    Male   52                 Private
# 1                1           2  Female   18  Social Security Agency
# 2                2           3  Female   46                 Private
# 3                3           4  Female   85  Social Security Agency
# 4                4           5    Male   21                 Private
# ...            ...         ...     ...  ...                     ...
# 499995      499995      499996  Female   67  Social Security Agency
# 499996      499996      499997  Female   65  Social Security Agency
# 499997      499997      499998  Female   36                 Private
# 499998      499998      499999  Female   56  Social Security Agency
# 499999      499999      500000  Female   30  Social Security Agency
#
#        smoking_status  e_cigarette_usage alcohol_consumption_rate  \
# 0               Never              False               Occasional
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                500000 non-null  int64
#  1   patient_id                500000 non-null  int64
#  2   gender                    500000 non-null  object
#  3   age                       500000 non-null  int64
#  4   insurance_type            500000 non-null  object
#  5   smoking_status            500000 non-null  object
#  6   e_cigarette_usage         500000 non-null  bool
#  7   alcohol_consumption_rate  312032 non-null  object
#  8   previous_admission_count  500000 non-null  int64
#  9   surgery_name              500000 non-null  object
#  10  surgery_type              500000 non-null  object
#  11  surgery_duration          500000 non-null  int64
#  12  room_type                 500000 non-null  object
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0     patient_id            age  previous_admission_count  \
# count  500000.000000  500000.000000  500000.000000             500000.000000
# mean   249999.500000  250000.500000      50.162344                  0.999698
# std    144337.711635  144337.711635      17.197786                  0.996054
# min         0.000000       1.000000      18.000000                  0.000000
# 25%    124999.750000  125000.750000      38.000000                  0.000000
# 50%    249999.500000  250000.500000      50.000000                  1.000000
# 75%    374999.250000  375000.250000      62.000000                  2.000000
# max    499999.000000  500000.000000      90.000000                  5.000000
#
#        surgery_duration  medical_equipment_count  stay_duration  \
# count     500000.000000            500000.000000  500000.000000
# mean         132.155398                 1.656316       7.386190
# std           64.389109                 1.225122       4.597622
# ...

# %%
fig, ax = plt.subplots(figsize = (12,7))
sns.countplot(data = df, x = 'stay_duration')
plt.xlabel("Stay Duration")
plt.ylabel("Count")
plt.title("Patient Stay Duration Distribution")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,7))
sns.histplot(data = df, x = 'total_cost')
plt.xlabel("Hospital Total Cost")
plt.ylabel("Count")
plt.title("Total Hospital Cost Distribution")
plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
